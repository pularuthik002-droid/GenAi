# %%
print("hello world")
print("hello world")
print("hello world")
print("hello world")
print("git push testing... ")
print("This is a test for git push from vscode.")
# Out:
# hello world
# hello world
# hello world
# hello world
# git push testing...
